# %% [markdown]
# Preprocessing to split PlantDoc to Labeled and Unlabeled

# %%
import os
import shutil
import random

# %%
random.seed(42)

source_dir = "c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train"
labeled_dir = "c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_labeled"
unlabeled_dir = "c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_unlabeled"

# %%
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)
    
    if not os.path.isdir(class_path):
        continue
    
    images = os.listdir(class_path)
    random.shuffle(images)
    
    split_idx = int(0.1 * len(images))  # 10%
    
    labeled_images = images[:split_idx]
    unlabeled_images = images[split_idx:]
    
    os.makedirs(os.path.join(labeled_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(unlabeled_dir, class_name), exist_ok=True)
    
    for img in labeled_images:
        shutil.copy(
            os.path.join(class_path, img),
            os.path.join(labeled_dir, class_name, img)
        )
    
    for img in unlabeled_images:
        shutil.copy(
            os.path.join(class_path, img),
            os.path.join(unlabeled_dir, class_name, img)
        )

print("Split complete ✅")
# Out:
# Split complete ✅

# %%
import os

print("Labeled classes:", len(os.listdir("c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_labeled")))
print("Unlabeled classes:", len(os.listdir("c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_unlabeled")))
# Out:
# Labeled classes: 28
# Unlabeled classes: 28

# %%
labeled_path = "c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_labeled"
unlabeled_path = "c:/Users/user/OneDrive/Desktop/fall 2025/Spring 2026/PlantDiseaseProject/data/plantdoc/train_unlabeled"

for class_name in os.listdir(labeled_path):
    labeled_count = len(os.listdir(os.path.join(labeled_path, class_name)))
    unlabeled_count = len(os.listdir(os.path.join(unlabeled_path, class_name)))
    
    print(class_name)
    print("  Labeled:", labeled_count)
    print("  Unlabeled:", unlabeled_count)
    print()
# Out:
# Apple leaf
#   Labeled: 8
#   Unlabeled: 73
#
# Apple rust leaf
#   Labeled: 7
#   Unlabeled: 71
#
# Apple Scab Leaf
#   Labeled: 8
#   Unlabeled: 75
#
# Bell_pepper leaf
#   Labeled: 5
#   Unlabeled: 48
#
# Bell_pepper leaf spot
#   Labeled: 6
#   Unlabeled: 56
#
# Blueberry leaf
#   Labeled: 10
#   Unlabeled: 93
#
# Cherry leaf
#   Labeled: 4
#   Unlabeled: 42
#
# Corn Gray leaf spot
#   Labeled: 6
#   Unlabeled: 58
#
# Corn leaf blight
#   Labeled: 17
#   Unlabeled: 162
#
# Corn rust leaf
#   Labeled: 10
#   Unlabeled: 96
#
# grape leaf
#   Labeled: 5
#   Unlabeled: 51
#
# grape leaf black rot
#   Labeled: 5
#   Unlabeled: 51
#
# Peach leaf
#   Labeled: 10
#   Unlabeled: 92
#
# Potato leaf early blight
#   Labeled: 10
#   Unlabeled: 98
#
# Potato leaf late blight
#   Labeled: 9
#   Unlabeled: 88
#
# Raspberry leaf
#   Labeled: 11
#   Unlabeled: 101
#
# Soyabean leaf
#   Labeled: 5
#   Unlabeled: 52
#
# Squash Powdery mildew leaf
#   Labeled: 12
#   Unlabeled: 110
#
# ...

# %% [markdown]
# Check if a class has zero for labeled picture and fixes this issue

# %%
for class_name in os.listdir(labeled_path):
    labeled_class_path = os.path.join(labeled_path, class_name)
    unlabeled_class_path = os.path.join(unlabeled_path, class_name)
    
    labeled_count = len(os.listdir(labeled_class_path))
    
    if labeled_count == 0:
        unlabeled_images = os.listdir(unlabeled_class_path)
        
        if len(unlabeled_images) > 0:
            img_to_move = random.choice(unlabeled_images)
            
            shutil.move(
                os.path.join(unlabeled_class_path, img_to_move),
                os.path.join(labeled_class_path, img_to_move)
            )
            
            print(f"Moved 1 image to labeled for class: {class_name}")

print("Fix complete ")
# Out:
# Fix complete
