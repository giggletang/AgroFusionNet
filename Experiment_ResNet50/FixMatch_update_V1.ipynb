# %%
# =========================
# FixMatch (start from baseline checkpoint)
#   Train with:
#       - PlantDoc/train_labeled
#       - PlantDoc/train_unlabeled_weak
#       - PlantDoc/train_unlabeled_strong
#   Evaluate on PlantDoc/test
# =========================

import os
import time
import json
import random
import shutil
from typing import Dict, List

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, models

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# =========================
# Paths and config
# =========================

DRIVE_ROOT = "/content/drive/MyDrive/dataset"

# Choose ONE starting checkpoint:
# 1) baseline checkpoint (source-only)
START_CKPT = "/content/drive/MyDrive/plant_disease_project/runs_supervised_baseline_new/best.pt"

# 2) OR fine-tuned checkpoint (usually gives better pseudo-label quality)
# START_CKPT = "/content/drive/MyDrive/plant_disease_project/runs_finetune_supervised_cleaned/finetune_best.pt"

DRIVE_PD_LABELED = f"{DRIVE_ROOT}/PlantDoc/train_labeled"
DRIVE_PD_UNLABELED_WEAK = f"{DRIVE_ROOT}/PlantDoc/train_unlabeled_weak"
DRIVE_PD_UNLABELED_STRONG = f"{DRIVE_ROOT}/PlantDoc/train_unlabeled_strong"
DRIVE_PD_TEST = f"{DRIVE_ROOT}/PlantDoc/test"

OUT_DIR = "/content/drive/MyDrive/plant_disease_project/runs_fixmatch_v1"
os.makedirs(OUT_DIR, exist_ok=True)

COPY_TO_LOCAL = True

MODEL_NAME = "resnet50"     # must match checkpoint model
EPOCHS = 20
WARMUP_EPOCHS = 2           # labeled-only warmup before FixMatch
LR = 1e-4
WEIGHT_DECAY = 1e-4
BATCH_SIZE_LABELED = 64
BATCH_SIZE_UNLABELED = 64
NUM_WORKERS = 2
USE_AMP = True
SEED = 42

# FixMatch hyperparameters
THRESHOLD = 0.95
LAMBDA_U = 0.25             # lower than before for more stable training

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("[Info] device =", device)
# Out:
# [Info] device = cuda

# %%
# =========================
# Sanity checks + remove empty folders from train_labeled
# =========================
if not os.path.isfile(START_CKPT):
    raise RuntimeError(f"[ERROR] Starting checkpoint not found: {START_CKPT}")

for p in [DRIVE_PD_LABELED, DRIVE_PD_UNLABELED_WEAK, DRIVE_PD_UNLABELED_STRONG, DRIVE_PD_TEST]:
    if not os.path.isdir(p):
        raise RuntimeError(f"[ERROR] Folder not found: {p}")

empty_dirs = []
for c in os.listdir(DRIVE_PD_LABELED):
    p = os.path.join(DRIVE_PD_LABELED, c)
    if os.path.isdir(p) and len(os.listdir(p)) == 0:
        empty_dirs.append(p)

for p in empty_dirs:
    print("[Removing empty folder]", p)
    shutil.rmtree(p)

print(f"[Info] Removed {len(empty_dirs)} empty folders from train_labeled")
# Out:
# [Info] Removed 0 empty folders from train_labeled

# %%
# =========================
# Load starting checkpoint
# =========================
ckpt = torch.load(START_CKPT, map_location="cpu")
print("[Info] checkpoint keys:", ckpt.keys())

if "classes" not in ckpt:
    raise RuntimeError("Checkpoint does not contain 'classes'. Please save classes inside the checkpoint.")

source_classes = ckpt["classes"]
num_classes = len(source_classes)
source_class_to_idx = {name: i for i, name in enumerate(source_classes)}

print("[Info] num_classes =", num_classes)
print("[Info] source classes =", source_classes)
# Out:
# [Info] checkpoint keys: dict_keys(['model_state_dict', 'epoch', 'best_acc', 'classes', 'model_name'])
# [Info] num_classes = 15
# [Info] source classes = ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
# =========================
# Transforms
# For weak/strong folders produced offline, use only deterministic tensor transforms
# =========================
normalize = transforms.Normalize([0.485, 0.456, 0.406],
                                 [0.229, 0.224, 0.225])

labeled_tf = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(0.5),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.05),
    transforms.ToTensor(),
    normalize,
])

eval_tf = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])

ssl_file_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalize,
])

# %%
# =========================
# PlantVillage -> PlantDoc class mapping
# Update names here ONLY if your folder names differ
# =========================
PV2PD = {
    "Pepper__bell___Bacterial_spot": "Bell_pepper leaf spot",
    "Pepper__bell___healthy": "Bell_pepper leaf",

    "Potato___Early_blight": "Potato leaf early blight",
    "Potato___Late_blight": "Potato leaf late blight",
    "Potato___healthy": None,

    "Tomato_Bacterial_spot": "Tomato leaf bacterial spot",
    "Tomato_Early_blight": "Tomato Early blight leaf",
    "Tomato_Late_blight": "Tomato leaf late blight",
    "Tomato_Leaf_Mold": "Tomato mold leaf",
    "Tomato_Septoria_leaf_spot": "Tomato Septoria leaf spot",
    "Tomato_Spider_mites_Two_spotted_spider_mite": "Tomato two spotted spider mites leaf",
    "Tomato__Target_Spot": None,
    "Tomato__Tomato_YellowLeaf__Curl_Virus": "Tomato leaf yellow virus",
    "Tomato__Tomato_mosaic_virus": "Tomato leaf mosaic virus",
    "Tomato_healthy": "Tomato leaf",
}

pd_folder_to_src_idx = {}
for pv_name, pd_name in PV2PD.items():
    if pd_name is None:
        continue
    if pv_name not in source_class_to_idx:
        continue
    pd_folder_to_src_idx[pd_name] = source_class_to_idx[pv_name]

mapped_pd_classes = sorted(pd_folder_to_src_idx.keys())

print("[Info] PlantDoc folder -> source label index mapping")
for k, v in pd_folder_to_src_idx.items():
    print(f"  {k} -> {v}")
print("[Info] mapped PlantDoc classes:", mapped_pd_classes)
# Out:
# [Info] PlantDoc folder -> source label index mapping
#   Bell_pepper leaf spot -> 0
#   Bell_pepper leaf -> 1
#   Potato leaf early blight -> 2
#   Potato leaf late blight -> 3
#   Tomato leaf bacterial spot -> 5
#   Tomato Early blight leaf -> 6
#   Tomato leaf late blight -> 7
#   Tomato mold leaf -> 8
#   Tomato Septoria leaf spot -> 9
#   Tomato two spotted spider mites leaf -> 10
#   Tomato leaf yellow virus -> 12
#   Tomato leaf mosaic virus -> 13
#   Tomato leaf -> 14
# [Info] mapped PlantDoc classes: ['Bell_pepper leaf', 'Bell_pepper leaf spot', 'Potato leaf early blight', 'Potato leaf late blight', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'Tomato two spotted spider mites leaf']

# %%
# =========================
# Dataset wrappers
# =========================
class MappedImageFolderDataset(Dataset):
    def __init__(self, imagefolder_ds, folder_to_newlabel):
        self.base = imagefolder_ds
        self.folder_to_newlabel = folder_to_newlabel
        self.keep_indices = []

        for i, (_, y) in enumerate(self.base.samples):
            folder_name = self.base.classes[y]
            if folder_name in self.folder_to_newlabel:
                self.keep_indices.append(i)

        self.class_counts = {}
        for i in self.keep_indices:
            _, y = self.base.samples[i]
            folder_name = self.base.classes[y]
            self.class_counts[folder_name] = self.class_counts.get(folder_name, 0) + 1

    def __len__(self):
        return len(self.keep_indices)

    def __getitem__(self, idx):
        real_idx = self.keep_indices[idx]
        x, old_y = self.base[real_idx]
        folder_name = self.base.classes[old_y]
        new_y = self.folder_to_newlabel[folder_name]
        return x, new_y


class PairedMappedUnlabeledDataset(Dataset):
    # keeps ONLY mapped classes and requires matched filenames across weak/strong
    def __init__(self, weak_root, strong_root, allowed_classes, transform=None):
        self.weak_root = weak_root
        self.strong_root = strong_root
        self.allowed_classes = set(allowed_classes)
        self.transform = transform
        self.samples = []

        weak_classes = sorted([d for d in os.listdir(weak_root) if os.path.isdir(os.path.join(weak_root, d))])

        skipped_unmapped_classes = []
        missing_strong_classes = []

        for cls_name in weak_classes:
            if cls_name not in self.allowed_classes:
                skipped_unmapped_classes.append(cls_name)
                continue

            weak_cls_dir = os.path.join(weak_root, cls_name)
            strong_cls_dir = os.path.join(strong_root, cls_name)

            if not os.path.isdir(strong_cls_dir):
                missing_strong_classes.append(cls_name)
                continue

            weak_files = sorted([f for f in os.listdir(weak_cls_dir) if os.path.isfile(os.path.join(weak_cls_dir, f))])
            strong_file_set = set([f for f in os.listdir(strong_cls_dir) if os.path.isfile(os.path.join(strong_cls_dir, f))])

            for fn in weak_files:
                if fn in strong_file_set:
                    weak_path = os.path.join(weak_cls_dir, fn)
                    strong_path = os.path.join(strong_cls_dir, fn)
                    self.samples.append((weak_path, strong_path, cls_name))

        self.class_counts = {}
        for _, _, cls_name in self.samples:
            self.class_counts[cls_name] = self.class_counts.get(cls_name, 0) + 1

        self.skipped_unmapped_classes = sorted(skipped_unmapped_classes)
        self.missing_strong_classes = sorted(missing_strong_classes)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        from PIL import Image

        weak_path, strong_path, cls_name = self.samples[idx]
        weak_img = Image.open(weak_path).convert("RGB")
        strong_img = Image.open(strong_path).convert("RGB")

        if self.transform is not None:
            weak_img = self.transform(weak_img)
            strong_img = self.transform(strong_img)

        return weak_img, strong_img

# %%
# =========================
# Load datasets
# =========================
pd_labeled_raw = datasets.ImageFolder(DRIVE_PD_LABELED, transform=labeled_tf)
pd_test_raw = datasets.ImageFolder(DRIVE_PD_TEST, transform=eval_tf)

pd_labeled_ds = MappedImageFolderDataset(pd_labeled_raw, pd_folder_to_src_idx)
pd_test_ds = MappedImageFolderDataset(pd_test_raw, pd_folder_to_src_idx)
pd_unlabeled_ds = PairedMappedUnlabeledDataset(
    DRIVE_PD_UNLABELED_WEAK,
    DRIVE_PD_UNLABELED_STRONG,
    allowed_classes=mapped_pd_classes,
    transform=ssl_file_tf
)

print("[Info] raw train_labeled classes:", pd_labeled_raw.classes)
print("[Info] raw test classes:", pd_test_raw.classes)

print("[Info] mapped train_labeled size:", len(pd_labeled_ds))
print("[Info] mapped test size:", len(pd_test_ds))
print("[Info] mapped unlabeled pair count:", len(pd_unlabeled_ds))

print("[Info] mapped train_labeled class counts:", pd_labeled_ds.class_counts)
print("[Info] mapped test class counts:", pd_test_ds.class_counts)
print("[Info] mapped unlabeled class counts:", pd_unlabeled_ds.class_counts)

unmapped_labeled = sorted(set(pd_labeled_raw.classes) - set(pd_folder_to_src_idx.keys()))
unmapped_test = sorted(set(pd_test_raw.classes) - set(pd_folder_to_src_idx.keys()))
print("[Info] unmapped classes in train_labeled:", unmapped_labeled)
print("[Info] unmapped classes in test:", unmapped_test)
print("[Info] skipped unmapped classes in unlabeled:", pd_unlabeled_ds.skipped_unmapped_classes)
print("[Info] missing strong classes in unlabeled:", pd_unlabeled_ds.missing_strong_classes)

if len(pd_labeled_ds) == 0:
    raise RuntimeError("Mapped train_labeled dataset is empty. Check folder names and class mapping.")
if len(pd_test_ds) == 0:
    raise RuntimeError("Mapped test dataset is empty. Check folder names and class mapping.")
if len(pd_unlabeled_ds) == 0:
    raise RuntimeError("Mapped unlabeled weak/strong dataset is empty. Check folders, filenames, and class mapping.")
# Out:
# [Info] raw train_labeled classes: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']
# [Info] raw test classes: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']
# [Info] mapped train_labeled size: 95
# [Info] mapped test size: 102
# [Info] mapped unlabeled pair count: 902
# [Info] mapped train_labeled class counts: {'Bell_pepper leaf': 5, 'Bell_pepper leaf spot': 6, 'Potato leaf early blight': 10, 'Potato leaf late blight': 9, 'Tomato Early blight leaf': 7, 'Tomato Septoria leaf spot': 14, 'Tomato leaf': 5, 'Tomato leaf bacterial spot': 10, 'Tomato leaf late blight': 10, 'Tomato leaf mosaic virus': 4, 'Tomato leaf yellow virus': 7, 'Tomato mold leaf': 8}
# [Info] mapped test class counts: {'Bell_pepper leaf': 8, 'Bell_pepper leaf spot': 9, 'Potato leaf early blight': 8, 'Potato leaf late blight': 8, 'Tomato Early blight leaf': 9, 'Tomato Septoria leaf spot': 11, 'Tomato leaf': 8, 'Tomato leaf bacterial spot': 9, 'Tomato leaf late blight': 10, 'Tomato leaf mosaic virus': 10, 'Tomato leaf yellow virus': 6, 'Tomato mold leaf': 6}
# [Info] mapped unlabeled class counts: {'Bell_pepper leaf': 48, 'Bell_pepper leaf spot': 56, 'Potato leaf early blight': 98, 'Potato leaf late blight': 88, 'Tomato Early blight leaf': 72, 'Tomato Septoria leaf spot': 126, 'Tomato leaf': 50, 'Tomato leaf bacterial spot': 91, 'Tomato leaf late blight': 91, 'Tomato leaf mosaic virus': 40, 'Tomato leaf yellow virus': 63, 'Tomato mold leaf': 77, 'Tomato two spotted spider mites leaf': 2}
# [Info] unmapped classes in train_labeled: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'grape leaf', 'grape leaf black rot']
# [Info] unmapped classes in test: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'grape leaf', 'grape leaf black rot']
# [Info] skipped unmapped classes in unlabeled: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'grape leaf', 'grape leaf black rot']
# [Info] missing strong classes in unlabeled: []

# %%
# =========================
# DataLoaders
# =========================
pd_labeled_loader = DataLoader(
    pd_labeled_ds,
    batch_size=BATCH_SIZE_LABELED,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=(device.type == "cuda"),
    drop_last=False
)

pd_unlabeled_loader = DataLoader(
    pd_unlabeled_ds,
    batch_size=BATCH_SIZE_UNLABELED,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=(device.type == "cuda"),
    drop_last=False
)

pd_test_loader = DataLoader(
    pd_test_ds,
    batch_size=BATCH_SIZE_LABELED,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=(device.type == "cuda"),
    drop_last=False
)

print("[Info] labeled batches:", len(pd_labeled_loader))
print("[Info] unlabeled batches:", len(pd_unlabeled_loader))
print("[Info] test batches:", len(pd_test_loader))
# Out:
# [Info] labeled batches: 2
# [Info] unlabeled batches: 15
# [Info] test batches: 2

# %%
# =========================
# Build model and load checkpoint weights
# =========================
def build_model(name: str, num_classes: int, pretrained: bool = False):
    name = name.lower()
    if name == "resnet18":
        m = models.resnet18(weights=models.ResNet18_Weights.DEFAULT if pretrained else None)
        m.fc = nn.Linear(m.fc.in_features, num_classes)
        return m
    if name == "resnet50":
        m = models.resnet50(weights=models.ResNet50_Weights.DEFAULT if pretrained else None)
        m.fc = nn.Linear(m.fc.in_features, num_classes)
        return m
    raise ValueError("Only resnet18/resnet50 supported.")

model = build_model(MODEL_NAME, num_classes=num_classes, pretrained=False)

if "model_state_dict" in ckpt:
    model.load_state_dict(ckpt["model_state_dict"])
elif "model" in ckpt:
    model.load_state_dict(ckpt["model"])
else:
    raise RuntimeError("Cannot find model weights inside checkpoint.")

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scaler = torch.amp.GradScaler("cuda", enabled=(USE_AMP and device.type == "cuda"))

print("[Info] Loaded checkpoint successfully.")
# Out:
# [Info] Loaded checkpoint successfully.

# %%
# =========================
# Metrics + Eval
# =========================
@torch.no_grad()
def confusion_matrix(pred: List[int], true: List[int], num_classes: int):
    cm = torch.zeros((num_classes, num_classes), dtype=torch.long)
    for p, t in zip(pred, true):
        cm[t, p] += 1
    return cm

def macro_f1_from_cm(cm):
    f1s = []
    for c in range(cm.size(0)):
        tp = cm[c, c].item()
        fp = cm[:, c].sum().item() - tp
        fn = cm[c, :].sum().item() - tp

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0.0
        f1s.append(f1)

    return float(sum(f1s) / len(f1s)) if len(f1s) > 0 else 0.0

@torch.no_grad()
def evaluate(loader):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_preds, all_true = [], []

    for x, y in loader:
        x, y = x.to(device), y.to(device)

        logits = model(x)
        loss = criterion(logits, y)
        pred = logits.argmax(1)

        total_loss += loss.item() * x.size(0)
        correct += (pred == y).sum().item()
        total += y.size(0)

        all_preds.extend(pred.cpu().tolist())
        all_true.extend(y.cpu().tolist())

    cm = confusion_matrix(all_preds, all_true, num_classes)
    macro_f1 = macro_f1_from_cm(cm)

    return {
        "loss": total_loss / max(1, total),
        "acc": correct / max(1, total),
        "macro_f1": macro_f1,
        "cm": cm
    }

# %%
# =========================
# Labeled-only warmup epoch
# =========================
def run_labeled_epoch(loader):
    model.train()
    total_loss, correct, total = 0.0, 0, 0

    for x, y in loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device_type="cuda", enabled=(USE_AMP and device.type == "cuda")):
            logits = model(x)
            loss = criterion(logits, y)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item() * x.size(0)
        pred = logits.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)

    return {
        "loss": total_loss / max(1, total),
        "train_acc": correct / max(1, total),
    }

# %%
# =========================
# FixMatch train epoch
# Uses ONLY:
#   - target labeled supervised loss
#   - target unlabeled FixMatch loss
# =========================
def run_fixmatch_epoch(labeled_loader, unlabeled_loader):
    model.train()

    total_loss = 0.0
    total_sup_loss = 0.0
    total_unsup_loss = 0.0
    total_correct = 0
    total_labeled = 0

    total_mask_selected = 0
    total_unlabeled = 0

    unlabeled_iter = iter(unlabeled_loader)

    for x_l, y_l in labeled_loader:
        try:
            x_u_w, x_u_s = next(unlabeled_iter)
        except StopIteration:
            unlabeled_iter = iter(unlabeled_loader)
            x_u_w, x_u_s = next(unlabeled_iter)

        x_l, y_l = x_l.to(device), y_l.to(device)
        x_u_w = x_u_w.to(device)
        x_u_s = x_u_s.to(device)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device_type="cuda", enabled=(USE_AMP and device.type == "cuda")):
            # supervised branch
            logits_l = model(x_l)
            loss_sup = criterion(logits_l, y_l)

            # pseudo labels from weak branch
            with torch.no_grad():
                logits_u_w = model(x_u_w)
                probs_u_w = torch.softmax(logits_u_w, dim=1)
                max_probs, pseudo_labels = torch.max(probs_u_w, dim=1)
                mask = max_probs.ge(THRESHOLD).float()

            # strong branch
            logits_u_s = model(x_u_s)
            per_sample_unsup = F.cross_entropy(logits_u_s, pseudo_labels, reduction="none")
            loss_unsup = (per_sample_unsup * mask).sum() / mask.sum().clamp(min=1.0)

            loss = loss_sup + LAMBDA_U * loss_unsup

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item() * x_l.size(0)
        total_sup_loss += loss_sup.item() * x_l.size(0)
        total_unsup_loss += loss_unsup.item() * x_l.size(0)

        pred_l = logits_l.argmax(1)
        total_correct += (pred_l == y_l).sum().item()
        total_labeled += y_l.size(0)

        total_mask_selected += int(mask.sum().item())
        total_unlabeled += int(mask.numel())

    return {
        "loss": total_loss / max(1, total_labeled),
        "sup_loss": total_sup_loss / max(1, total_labeled),
        "unsup_loss": total_unsup_loss / max(1, total_labeled),
        "train_acc": total_correct / max(1, total_labeled),
        "mask_rate": total_mask_selected / max(1, total_unlabeled),
    }

# %%
# =========================
# Train loop
# =========================
best_path = os.path.join(OUT_DIR, "fixmatch_best.pt")
log_path = os.path.join(OUT_DIR, "fixmatch_log.json")
cm_path = os.path.join(OUT_DIR, "fixmatch_confusion_matrix.txt")

best_acc = -1.0
log = []

print("\n========== FixMatch with mapped unlabeled classes ==========")

# Stage 1: labeled-only warmup
for epoch in range(1, WARMUP_EPOCHS + 1):
    t0 = time.time()

    tr = run_labeled_epoch(pd_labeled_loader)
    ev = evaluate(pd_test_loader)

    row = {
        "stage": "warmup",
        "epoch": epoch,
        "train_loss": float(tr["loss"]),
        "train_acc": float(tr["train_acc"]),
        "pd_test_loss": float(ev["loss"]),
        "pd_test_acc": float(ev["acc"]),
        "pd_test_macro_f1": float(ev["macro_f1"]),
        "sec": float(time.time() - t0)
    }
    log.append(row)

    print(
        f"[Warmup] Epoch {epoch:03d}/{WARMUP_EPOCHS} | "
        f"train_labeled loss {tr['loss']:.4f} acc {tr['train_acc']:.4f} | "
        f"PlantDoc test loss {ev['loss']:.4f} acc {ev['acc']:.4f} macroF1 {ev['macro_f1']:.4f} | "
        f"{time.time()-t0:.1f}s"
    )

    if ev["acc"] > best_acc:
        best_acc = ev["acc"]
        torch.save({
            "model_state_dict": model.state_dict(),
            "best_acc": best_acc,
            "epoch": epoch,
            "stage": "warmup",
            "classes": source_classes,
            "model_name": MODEL_NAME,
            "start_ckpt": START_CKPT,
            "threshold": THRESHOLD,
            "lambda_u": LAMBDA_U,
        }, best_path)

# Stage 2: FixMatch
for epoch in range(1, EPOCHS + 1):
    t0 = time.time()

    tr = run_fixmatch_epoch(pd_labeled_loader, pd_unlabeled_loader)
    ev = evaluate(pd_test_loader)

    row = {
        "stage": "fixmatch",
        "epoch": epoch,
        "train_loss": float(tr["loss"]),
        "sup_loss": float(tr["sup_loss"]),
        "unsup_loss": float(tr["unsup_loss"]),
        "train_acc": float(tr["train_acc"]),
        "mask_rate": float(tr["mask_rate"]),
        "pd_test_loss": float(ev["loss"]),
        "pd_test_acc": float(ev["acc"]),
        "pd_test_macro_f1": float(ev["macro_f1"]),
        "sec": float(time.time() - t0)
    }
    log.append(row)

    print(
        f"[FixMatch] Epoch {epoch:03d}/{EPOCHS} | "
        f"train loss {tr['loss']:.4f} sup {tr['sup_loss']:.4f} unsup {tr['unsup_loss']:.4f} "
        f"acc {tr['train_acc']:.4f} mask {tr['mask_rate']:.4f} | "
        f"PlantDoc test loss {ev['loss']:.4f} acc {ev['acc']:.4f} macroF1 {ev['macro_f1']:.4f} | "
        f"{time.time()-t0:.1f}s"
    )

    if ev["acc"] > best_acc:
        best_acc = ev["acc"]
        torch.save({
            "model_state_dict": model.state_dict(),
            "best_acc": best_acc,
            "epoch": epoch,
            "stage": "fixmatch",
            "classes": source_classes,
            "model_name": MODEL_NAME,
            "start_ckpt": START_CKPT,
            "threshold": THRESHOLD,
            "lambda_u": LAMBDA_U,
        }, best_path)

with open(log_path, "w", encoding="utf-8") as f:
    json.dump(log, f, indent=2, ensure_ascii=False)

final_ev = evaluate(pd_test_loader)
with open(cm_path, "w", encoding="utf-8") as f:
    f.write("Confusion Matrix (rows=true, cols=pred)\n")
    f.write(str(final_ev["cm"].tolist()) + "\n")
    f.write(f"Final Acc: {final_ev['acc']:.6f}\n")
    f.write(f"Final Macro-F1: {final_ev['macro_f1']:.6f}\n")

print("\n[Done] best PlantDoc test acc =", best_acc)
print("[Saved] best checkpoint:", best_path)
print("[Saved] training log:", log_path)
print("[Saved] confusion matrix:", cm_path)
# Out:
# ========== FixMatch with mapped unlabeled classes ==========
# [Warmup] Epoch 001/2 | train_labeled loss 4.7619 acc 0.2211 | PlantDoc test loss 3.8058 acc 0.3333 macroF1 0.2428 | 1.4s
# [Warmup] Epoch 002/2 | train_labeled loss 3.5132 acc 0.2421 | PlantDoc test loss 3.4565 acc 0.3431 macroF1 0.2516 | 1.7s
# [FixMatch] Epoch 001/20 | train loss 2.9885 sup 2.9610 unsup 0.1099 acc 0.3579 mask 0.0859 | PlantDoc test loss 2.9717 acc 0.3333 macroF1 0.2472 | 12.7s
# [FixMatch] Epoch 002/20 | train loss 2.5275 sup 2.4441 unsup 0.3338 acc 0.3474 mask 0.0781 | PlantDoc test loss 2.7499 acc 0.3137 macroF1 0.2387 | 9.5s
# [FixMatch] Epoch 003/20 | train loss 2.1658 sup 2.0688 unsup 0.3880 acc 0.3684 mask 0.0781 | PlantDoc test loss 2.5891 acc 0.3235 macroF1 0.2511 | 10.0s
# [FixMatch] Epoch 004/20 | train loss 1.8332 sup 1.8060 unsup 0.1089 acc 0.4526 mask 0.0625 | PlantDoc test loss 2.4647 acc 0.3137 macroF1 0.2412 | 8.5s
# [FixMatch] Epoch 005/20 | train loss 1.5990 sup 1.5656 unsup 0.1339 acc 0.5474 mask 0.0938 | PlantDoc test loss 2.3703 acc 0.3333 macroF1 0.2554 | 7.9s
# [FixMatch] Epoch 006/20 | train loss 1.4959 sup 1.4132 unsup 0.3310 acc 0.6105 mask 0.0625 | PlantDoc test loss 2.2992 acc 0.3431 macroF1 0.2606 | 5.4s
# [FixMatch] Epoch 007/20 | train loss 1.3050 sup 1.2616 unsup 0.1736 acc 0.6105 mask 0.0859 | PlantDoc test loss 2.2560 acc 0.3627 macroF1 0.2809 | 6.8s
# [FixMatch] Epoch 008/20 | train loss 1.1129 sup 1.0819 unsup 0.1243 acc 0.6737 mask 0.0703 | PlantDoc test loss 2.2198 acc 0.3627 macroF1 0.2746 | 7.1s
# [FixMatch] Epoch 009/20 | train loss 1.0584 sup 1.0125 unsup 0.1835 acc 0.6632 mask 0.1016 | PlantDoc test loss 2.2050 acc 0.3725 macroF1 0.2854 | 10.3s
# [FixMatch] Epoch 010/20 | train loss 0.9964 sup 0.8641 unsup 0.5294 acc 0.7684 mask 0.1016 | PlantDoc test loss 2.1860 acc 0.3824 macroF1 0.2872 | 5.6s
# [FixMatch] Epoch 011/20 | train loss 1.0398 sup 0.8163 unsup 0.8943 acc 0.7368 mask 0.0859 | PlantDoc test loss 2.1803 acc 0.3922 macroF1 0.2927 | 5.0s
# [FixMatch] Epoch 012/20 | train loss 0.8510 sup 0.7394 unsup 0.4464 acc 0.7263 mask 0.1094 | PlantDoc test loss 2.1952 acc 0.4020 macroF1 0.3008 | 6.4s
# [FixMatch] Epoch 013/20 | train loss 0.7379 sup 0.6071 unsup 0.5233 acc 0.8000 mask 0.1094 | PlantDoc test loss 2.1887 acc 0.3922 macroF1 0.2955 | 7.6s
# [FixMatch] Epoch 014/20 | train loss 0.6278 sup 0.6041 unsup 0.0947 acc 0.7789 mask 0.1641 | PlantDoc test loss 2.2081 acc 0.4118 macroF1 0.3076 | 5.6s
# [FixMatch] Epoch 015/20 | train loss 0.5630 sup 0.5261 unsup 0.1475 acc 0.8632 mask 0.1484 | PlantDoc test loss 2.2363 acc 0.3824 macroF1 0.2817 | 2.5s
# [FixMatch] Epoch 016/20 | train loss 0.5833 sup 0.4636 unsup 0.4787 acc 0.8526 mask 0.1484 | PlantDoc test loss 2.2675 acc 0.3824 macroF1 0.2824 | 3.4s
# [FixMatch] Epoch 017/20 | train loss 0.4488 sup 0.4035 unsup 0.1811 acc 0.8842 mask 0.2422 | PlantDoc test loss 2.3063 acc 0.3627 macroF1 0.2641 | 2.3s
# [FixMatch] Epoch 018/20 | train loss 0.3547 sup 0.3411 unsup 0.0546 acc 0.9158 mask 0.1562 | PlantDoc test loss 2.3029 acc 0.3333 macroF1 0.2445 | 2.3s
# [FixMatch] Epoch 019/20 | train loss 0.3055 sup 0.2639 unsup 0.1660 acc 0.9263 mask 0.2344 | PlantDoc test loss 2.3618 acc 0.3431 macroF1 0.2465 | 4.0s
# [FixMatch] Epoch 020/20 | train loss 0.2613 sup 0.2127 unsup 0.1940 acc 0.9684 mask 0.2188 | PlantDoc test loss 2.4061 acc 0.3431 macroF1 0.2478 | 4.2s
#
# [Done] best PlantDoc test acc = 0.4117647058823529
# [Saved] best checkpoint: /content/drive/MyDrive/plant_disease_project/runs_fixmatch_v1/fixmatch_best.pt
# [Saved] training log: /content/drive/MyDrive/plant_disease_project/runs_fixmatch_v1/fixmatch_log.json
# [Saved] confusion matrix: /content/drive/MyDrive/plant_disease_project/runs_fixmatch_v1/fixmatch_confusion_matrix.txt
