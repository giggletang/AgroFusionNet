# %%
import torch
print("CUDA:", torch.cuda.is_available())
# !nvidia-smi
# Out:
# CUDA: True
# Fri Apr 17 02:29:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8             13W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os, math, random, time
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms, models
from PIL import Image

def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

##for f in os.listdir("/content/drive/MyDrive"):
   ## print(f)

# %%
PROJECT = "/content/drive/MyDrive/PlantDiseaseProject"

print(os.listdir(PROJECT))
# Out:
# ['preprocessing', 'ssl.ipynb', 'data', 'shared_zip_or_raw', 'data_extracted', 'preprocessed', 'student2_dann_fixmatch_epoch_1.pth', 'student2_dann_fixmatch_epoch_2.pth', 'student2_dann_fixmatch_epoch_3.pth', 'student2_dann_fixmatch_epoch_4.pth', 'student2_dann_fixmatch_epoch_5.pth', 'student2_dann_fixmatch_best.pth', 'confusion_matrix_best.png', 'final_metrics.txt', 'plant_dann_fixmatch_model_updated01.ipynb', 'image']

# %%
# ===============================
# DATASET PATHS
# ===============================

SOURCE_DIR = "/content/drive/MyDrive/PlantDiseaseProject/data/plantvillage"

TARGET_ROOT = "/content/drive/MyDrive/PlantDiseaseProject/data/plantdoc"

TARGET_LABELED_DIR = f"{TARGET_ROOT}/train_labeled"
TARGET_UNLABELED_DIR = f"{TARGET_ROOT}/train_unlabeled"
TARGET_TEST_DIR = f"{TARGET_ROOT}/test"

print("SOURCE:", SOURCE_DIR)
print("TARGET LABELED:", TARGET_LABELED_DIR)
print("TARGET UNLABELED:", TARGET_UNLABELED_DIR)
print("TARGET TEST:", TARGET_TEST_DIR)
# Out:
# SOURCE: /content/drive/MyDrive/PlantDiseaseProject/data/plantvillage
# TARGET LABELED: /content/drive/MyDrive/PlantDiseaseProject/data/plantdoc/train_labeled
# TARGET UNLABELED: /content/drive/MyDrive/PlantDiseaseProject/data/plantdoc/train_unlabeled
# TARGET TEST: /content/drive/MyDrive/PlantDiseaseProject/data/plantdoc/test

# %%
import os

classes = os.listdir(SOURCE_DIR)

print("Number of classes:", len(classes))
print("Example classes:", classes[:10])
# Out:
# Number of classes: 15
# Example classes: ['Tomato__Tomato_mosaic_virus', 'Tomato__Target_Spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Septoria_leaf_spot', 'Tomato_Leaf_Mold', 'Tomato_Late_blight', 'Tomato_healthy', 'Tomato_Early_blight', 'Tomato_Bacterial_spot']

# %%
print("SOURCE exists:", os.path.exists(SOURCE_DIR))
print("TARGET_LABELED exists:", os.path.exists(TARGET_LABELED_DIR))
print("TARGET_UNLABELED exists:", os.path.exists(TARGET_UNLABELED_DIR))
print("TARGET_TEST exists:", os.path.exists(TARGET_TEST_DIR))
# Out:
# SOURCE exists: True
# TARGET_LABELED exists: True
# TARGET_UNLABELED exists: True
# TARGET_TEST exists: True

# %% [markdown]
# FixMatch augmentations (weak + strong)

# %%
imagenet_norm = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)

weak_tf = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    imagenet_norm
])

strong_tf = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.6, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply(
        [transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)],
        p=0.8
    ),
    transforms.RandomGrayscale(p=0.2),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.ToTensor(),
    imagenet_norm
])

test_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    imagenet_norm
])

# %% [markdown]
# label_map

# %%
label_map = {
    'Bell_pepper leaf': 'Pepper__bell___healthy',
    'Bell_pepper leaf spot': 'Pepper__bell___Bacterial_spot',
    'Tomato Early blight leaf': 'Tomato_Early_blight',
    'Tomato Septoria leaf spot': 'Tomato_Septoria_leaf_spot',
    'Tomato leaf': 'Tomato_healthy',
    'Tomato leaf bacterial spot': 'Tomato_Bacterial_spot',
    'Tomato leaf late blight': 'Tomato_Late_blight',
    'Tomato leaf mosaic virus': 'Tomato__Tomato_mosaic_virus',
    'Tomato leaf yellow virus': 'Tomato__Tomato_YellowLeaf__Curl_Virus',
    'Tomato mold leaf': 'Tomato_Leaf_Mold',
}

# %%
class MappedPlantDoc(Dataset):
    def __init__(self, root, transform, label_map, source_idx_map):
        self.transform = transform
        self.samples = []

        for folder in os.listdir(root):
            if folder in label_map:
                source_folder_name = label_map[folder]
                target_label = source_idx_map[source_folder_name]
                folder_path = os.path.join(root, folder)

                if os.path.isdir(folder_path):
                    for img_name in os.listdir(folder_path):
                        img_path = os.path.join(folder_path, img_name)
                        self.samples.append((img_path, target_label))

        print(f"Loaded {len(self.samples)} valid samples from {root}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        img = Image.open(path).convert("RGB")
        img = self.transform(img)
        return img, label

# %% [markdown]
# Datasets paired weak/strong on the SAME target image

# %%
class FixMatchTargetDataset(Dataset):

    def __init__(self, root, weak_transform, strong_transform):
        self.base = datasets.ImageFolder(root)
        self.weak_transform = weak_transform
        self.strong_transform = strong_transform

    def __len__(self):
        return len(self.base.samples)

    def __getitem__(self, idx):
        path, _ = self.base.samples[idx]
        img = Image.open(path).convert("RGB")
        xw = self.weak_transform(img)
        xs = self.strong_transform(img)
        return xw, xs

# Source labeled dataset
src_ds = datasets.ImageFolder(SOURCE_DIR, transform=weak_tf)
source_idx_map = src_ds.class_to_idx
num_classes = len(src_ds.classes)
print("num_classes:", num_classes)

# Target unlabeled dataset (FixMatch)
tgt_unlabeled_ds = FixMatchTargetDataset(
    TARGET_UNLABELED_DIR,
    weak_tf,
    strong_tf
)

# Target labeled dataset (mapped)
tgt_labeled_ds = MappedPlantDoc(
    TARGET_LABELED_DIR,
    transform=test_tf,
    label_map=label_map,
    source_idx_map=source_idx_map
)

# Target test dataset (mapped)
tgt_test_ds = MappedPlantDoc(
    TARGET_TEST_DIR,
    transform=test_tf,
    label_map=label_map,
    source_idx_map=source_idx_map
)

batch_size = 32

src_loader = DataLoader(
    src_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    drop_last=True
)

tgt_unlabeled_loader = DataLoader(
    tgt_unlabeled_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    drop_last=True
)

tgt_labeled_loader = DataLoader(
    tgt_labeled_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    drop_last=True
)

tgt_test_loader = DataLoader(
    tgt_test_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

print("Source samples:", len(src_ds))
print("Target unlabeled samples:", len(tgt_unlabeled_ds))
print("Target labeled samples:", len(tgt_labeled_ds))
print("Target test samples:", len(tgt_test_ds))
# Out:
# num_classes: 15
# Loaded 75 valid samples from /content/drive/MyDrive/PlantDiseaseProject/data/plantdoc/train_labeled
# Loaded 86 valid samples from /content/drive/MyDrive/PlantDiseaseProject/data/plantdoc/test
# Source samples: 20638
# Target unlabeled samples: 2099
# Target labeled samples: 75
# Target test samples: 86

# %% [markdown]
# GRL (Gradient Reversal Layer)

# %%
from torch.autograd import Function

class GradReverse(Function):
    @staticmethod
    def forward(ctx, x, lambd):
        ctx.lambd = lambd
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return -ctx.lambd * grad_output, None

def grl(x, lambd=1.0):
    return GradReverse.apply(x, lambd)

# %% [markdown]
# DANN model (ResNet50 backbone)

# %%
class DANNFixMatch(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        m = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        feat_dim = m.fc.in_features
        m.fc = nn.Identity()
        self.feature_extractor = m

        self.classifier = nn.Sequential(
            nn.Linear(feat_dim, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(512, num_classes),
        )

        self.domain_disc = nn.Sequential(
            nn.Linear(feat_dim, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.2),
            nn.Linear(512, 1)
        )

    def forward(self, x, grl_lambda=1.0):
        feats = self.feature_extractor(x)

        if feats.dim() > 2:
            feats = torch.flatten(feats, 1)

        cls_logits = self.classifier(feats)
        dom_logits = self.domain_disc(grl(feats, grl_lambda))
        return cls_logits, dom_logits

model = DANNFixMatch(num_classes=num_classes).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 152MB/s]

# %% [markdown]
# Loss functions + schedules (DANN + FixMatch)

# %%
ce = nn.CrossEntropyLoss()
bce = nn.BCEWithLogitsLoss()

@torch.no_grad()
def pseudo_labels(logits, tau=0.95):
    probs = torch.softmax(logits, dim=1)
    conf, yhat = torch.max(probs, dim=1)
    mask = (conf >= tau).float()
    return yhat.detach(), mask.detach()

def grl_lambda_schedule(step, max_steps):
    p = float(step) / float(max_steps)
    return 2.0 / (1.0 + math.exp(-10 * p)) - 1.0

# %% [markdown]
# Training loop
# Source supervised classification
#
# Target FixMatch consistency
#
# Domain adversarial loss (source vs target)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)

epochs = 20
tau = 0.90
lambda_domain = 0.5
lambda_fix = 1.0

steps_per_epoch = min(len(src_loader), len(tgt_unlabeled_loader))
max_steps = epochs * steps_per_epoch

global_step = 0
best_loss = float("inf")

for epoch in range(1, epochs + 1):
    model.train()
    running = {"cls": 0.0, "dom": 0.0, "fix": 0.0, "tot": 0.0, "accept": 0.0}

    src_iter = iter(src_loader)
    tgt_iter = iter(tgt_unlabeled_loader)

    for step in range(steps_per_epoch):
        xs, ys = next(src_iter)              # source labeled
        xw, xstrong = next(tgt_iter)         # target unlabeled: weak + strong

        xs, ys = xs.to(device), ys.to(device)
        xw = xw.to(device)
        xstrong = xstrong.to(device)

        grl_l = grl_lambda_schedule(global_step, max_steps)

        # Source branch
        src_cls_logits, src_dom_logits = model(xs, grl_lambda=grl_l)
        loss_cls = ce(src_cls_logits, ys)

        # Target unlabeled branch (FixMatch)
        tgt_w_logits, tgt_w_dom_logits = model(xw, grl_lambda=grl_l)
        yhat, mask = pseudo_labels(tgt_w_logits.detach(), tau=tau)

        tgt_s_logits, _ = model(xstrong, grl_lambda=grl_l)
        loss_fix = (F.cross_entropy(tgt_s_logits, yhat, reduction="none") * mask).mean()

        # Domain loss
        dom_src = torch.zeros((xs.size(0), 1), device=device)
        dom_tgt = torch.ones((xw.size(0), 1), device=device)

        loss_dom = 0.5 * (
            bce(src_dom_logits, dom_src) +
            bce(tgt_w_dom_logits, dom_tgt)
        )

        # Total loss
        loss = loss_cls + lambda_domain * loss_dom + lambda_fix * loss_fix

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
        optimizer.step()

        running["cls"] += float(loss_cls.item())
        running["dom"] += float(loss_dom.item())
        running["fix"] += float(loss_fix.item())
        running["tot"] += float(loss.item())
        running["accept"] += float(mask.mean().item())

        global_step += 1

        if (step + 1) % 50 == 0:
            n = step + 1
            print(
                f"Epoch {epoch}/{epochs} Step {step+1}/{steps_per_epoch} | "
                f"cls {running['cls']/n:.3f} dom {running['dom']/n:.3f} "
                f"fix {running['fix']/n:.3f} tot {running['tot']/n:.3f} "
                f"| pseudo-accept {running['accept']/n:.2f}"
            )

    n = steps_per_epoch
    epoch_loss = running["tot"] / n

    print(
        f"Epoch {epoch} done | cls {running['cls']/n:.3f} "
        f"dom {running['dom']/n:.3f} fix {running['fix']/n:.3f} "
        f"tot {epoch_loss:.3f} | pseudo-accept {running['accept']/n:.2f}"
    )

    # Save checkpoint each epoch
    ckpt_path = f"/content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_{epoch}.pth"
    torch.save({
        "epoch": epoch,
        "model_state": model.state_dict(),
        "classes": src_ds.classes,
        "num_classes": num_classes,
        "tau": tau,
        "lambda_domain": lambda_domain,
        "lambda_fix": lambda_fix,
    }, ckpt_path)
    print("Saved:", ckpt_path)

    # Save best model
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        best_ckpt_path = "/content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth"
        torch.save({
            "epoch": epoch,
            "model_state": model.state_dict(),
            "classes": src_ds.classes,
            "num_classes": num_classes,
            "tau": tau,
            "lambda_domain": lambda_domain,
            "lambda_fix": lambda_fix,
        }, best_ckpt_path)
        print("Saved best model:", best_ckpt_path)
# Out:
# Epoch 1/20 Step 50/65 | cls 1.430 dom 0.536 fix 0.002 tot 1.700 | pseudo-accept 0.01
# Epoch 1 done | cls 1.211 dom 0.510 fix 0.013 tot 1.479 | pseudo-accept 0.02
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_1.pth
# Saved best model: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth
# Epoch 2/20 Step 50/65 | cls 0.361 dom 0.469 fix 0.075 tot 0.671 | pseudo-accept 0.13
# Epoch 2 done | cls 0.353 dom 0.524 fix 0.079 tot 0.694 | pseudo-accept 0.14
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_2.pth
# Saved best model: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth
# Epoch 3/20 Step 50/65 | cls 0.285 dom 0.460 fix 0.130 tot 0.645 | pseudo-accept 0.32
# Epoch 3 done | cls 0.269 dom 0.439 fix 0.137 tot 0.625 | pseudo-accept 0.34
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_3.pth
# Saved best model: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth
# Epoch 4/20 Step 50/65 | cls 0.251 dom 0.583 fix 0.178 tot 0.721 | pseudo-accept 0.47
# Epoch 4 done | cls 0.247 dom 0.606 fix 0.161 tot 0.711 | pseudo-accept 0.47
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_4.pth
# Epoch 5/20 Step 50/65 | cls 0.234 dom 0.638 fix 0.191 tot 0.744 | pseudo-accept 0.57
# Epoch 5 done | cls 0.235 dom 0.642 fix 0.181 tot 0.737 | pseudo-accept 0.58
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_5.pth
# Epoch 6/20 Step 50/65 | cls 0.232 dom 0.549 fix 0.187 tot 0.693 | pseudo-accept 0.62
# Epoch 6 done | cls 0.230 dom 0.547 fix 0.176 tot 0.679 | pseudo-accept 0.61
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_6.pth
# Epoch 7/20 Step 50/65 | cls 0.204 dom 0.555 fix 0.145 tot 0.626 | pseudo-accept 0.62
# Epoch 7 done | cls 0.204 dom 0.579 fix 0.166 tot 0.659 | pseudo-accept 0.64
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_7.pth
# Epoch 8/20 Step 50/65 | cls 0.180 dom 0.623 fix 0.228 tot 0.720 | pseudo-accept 0.59
# Epoch 8 done | cls 0.193 dom 0.614 fix 0.222 tot 0.722 | pseudo-accept 0.59
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_8.pth
# Epoch 9/20 Step 50/65 | cls 0.149 dom 0.568 fix 0.183 tot 0.616 | pseudo-accept 0.58
# Epoch 9 done | cls 0.177 dom 0.577 fix 0.190 tot 0.655 | pseudo-accept 0.59
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_9.pth
# Epoch 10/20 Step 50/65 | cls 0.172 dom 0.545 fix 0.144 tot 0.589 | pseudo-accept 0.57
# Epoch 10 done | cls 0.169 dom 0.542 fix 0.156 tot 0.596 | pseudo-accept 0.57
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_10.pth
# Saved best model: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth
# Epoch 11/20 Step 50/65 | cls 0.210 dom 0.569 fix 0.205 tot 0.700 | pseudo-accept 0.58
# Epoch 11 done | cls 0.200 dom 0.570 fix 0.202 tot 0.686 | pseudo-accept 0.58
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_11.pth
# Epoch 12/20 Step 50/65 | cls 0.147 dom 0.505 fix 0.152 tot 0.552 | pseudo-accept 0.59
# Epoch 12 done | cls 0.136 dom 0.519 fix 0.158 tot 0.554 | pseudo-accept 0.60
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_12.pth
# Saved best model: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth
# Epoch 13/20 Step 50/65 | cls 0.160 dom 0.555 fix 0.200 tot 0.637 | pseudo-accept 0.62
# Epoch 13 done | cls 0.159 dom 0.548 fix 0.200 tot 0.634 | pseudo-accept 0.60
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_13.pth
# Epoch 14/20 Step 50/65 | cls 0.150 dom 0.592 fix 0.207 tot 0.654 | pseudo-accept 0.59
# Epoch 14 done | cls 0.151 dom 0.597 fix 0.210 tot 0.660 | pseudo-accept 0.59
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_14.pth
# Epoch 15/20 Step 50/65 | cls 0.152 dom 0.547 fix 0.207 tot 0.633 | pseudo-accept 0.65
# Epoch 15 done | cls 0.160 dom 0.547 fix 0.201 tot 0.635 | pseudo-accept 0.64
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_15.pth
# Epoch 16/20 Step 50/65 | cls 0.128 dom 0.605 fix 0.193 tot 0.623 | pseudo-accept 0.66
# Epoch 16 done | cls 0.124 dom 0.600 fix 0.211 tot 0.635 | pseudo-accept 0.66
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_16.pth
# Epoch 17/20 Step 50/65 | cls 0.146 dom 0.593 fix 0.287 tot 0.729 | pseudo-accept 0.60
# Epoch 17 done | cls 0.148 dom 0.583 fix 0.268 tot 0.707 | pseudo-accept 0.60
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_17.pth
# Epoch 18/20 Step 50/65 | cls 0.141 dom 0.579 fix 0.215 tot 0.645 | pseudo-accept 0.58
# Epoch 18 done | cls 0.143 dom 0.580 fix 0.213 tot 0.646 | pseudo-accept 0.58
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_18.pth
# Epoch 19/20 Step 50/65 | cls 0.142 dom 0.576 fix 0.162 tot 0.592 | pseudo-accept 0.65
# Epoch 19 done | cls 0.137 dom 0.573 fix 0.183 tot 0.607 | pseudo-accept 0.65
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_19.pth
# Epoch 20/20 Step 50/65 | cls 0.123 dom 0.576 fix 0.194 tot 0.605 | pseudo-accept 0.62
# Epoch 20 done | cls 0.126 dom 0.580 fix 0.182 tot 0.598 | pseudo-accept 0.61
# Saved: /content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_20.pth

# %% [markdown]
# Evaluation

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# Load the best saved checkpoint

# %%
CKPT_PATH = "/content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_best.pth"

checkpoint = torch.load(CKPT_PATH, map_location=device)

# handle both naming cases safely
if "model_state" in checkpoint:
    model.load_state_dict(checkpoint["model_state"])
elif "model_state_dict" in checkpoint:
    model.load_state_dict(checkpoint["model_state_dict"])
else:
    raise KeyError("Model state not found in checkpoint")

model.eval()

print("Loaded checkpoint from epoch:", checkpoint.get("epoch", "unknown"))
# Out:
# Loaded checkpoint from epoch: 12

# %%
def evaluate_model(model, loader, device, source_idx_map):
    model.eval()

    all_preds = []
    all_labels = []

    inv_map = {v: k for k, v in source_idx_map.items()}

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images, grl_lambda=0.0)

            # DANN model returns (class_logits, domain_logits)
            if isinstance(outputs, tuple):
                outputs = outputs[0]

            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    unique_labels = np.unique(all_labels)
    class_names = [inv_map[i] for i in unique_labels]

    acc = accuracy_score(all_labels, all_preds)
    macro_f1 = f1_score(all_labels, all_preds, average="macro")

    print(f"Accuracy: {acc*100:.2f}%")
    print(f"Macro F1: {macro_f1:.4f}")

    print("\nClassification Report:")
    print(classification_report(
        all_labels,
        all_preds,
        labels=unique_labels,
        target_names=class_names,
        zero_division=0
    ))

    cm = confusion_matrix(all_labels, all_preds, labels=unique_labels)

    return acc, macro_f1, cm, class_names

# %% [markdown]
# Run evaluation on test loader

# %%
acc, macro_f1, cm, class_names = evaluate_model(
    model,
    tgt_test_loader,
    device,
    source_idx_map
)
# Out:
# Accuracy: 27.91%
# Macro F1: 0.1701
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.00      0.00      0.00         9
#                Pepper__bell___healthy       0.50      0.38      0.43         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       1.00      0.11      0.20         9
#                    Tomato_Late_blight       0.26      1.00      0.42        10
#                      Tomato_Leaf_Mold       0.50      0.33      0.40         6
#             Tomato_Septoria_leaf_spot       0.43      0.55      0.48        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.33      0.25      0.29         8
#
#                             micro avg       0.31      0.28      0.29        86
#                             macro avg       0.30      0.26      0.22        86
#                          weighted avg       0.30      0.28      0.23        86

# %% [markdown]
# Run evaluation on your test loader

# %%
fig, ax = plt.subplots(figsize=(12, 10))

# Normalize confusion matrix (row-wise)
cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

im = ax.imshow(cm_normalized)
fig.colorbar(im, ax=ax)

# Clean class names (shorten)
short_names = [name.replace("Tomato__", "").replace("Pepper__bell___", "") for name in class_names]

ax.set_title("Normalized Confusion Matrix")
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")

ax.set_xticks(np.arange(len(short_names)))
ax.set_yticks(np.arange(len(short_names)))
ax.set_xticklabels(short_names, rotation=45, ha="right", fontsize=8)
ax.set_yticklabels(short_names, fontsize=8)

# Add values
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        val = cm_normalized[i, j]
        ax.text(
            j, i, f"{val:.2f}",
            ha="center", va="center",
            color="white" if val > 0.5 else "black",
            fontsize=7
        )

plt.tight_layout()


plt.savefig("confusion_matrix.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# Save confusion matrix plot to Drive

# %%
fig, ax = plt.subplots(figsize=(12, 10))

im = ax.imshow(cm, interpolation="nearest")
fig.colorbar(im, ax=ax)

ax.set_title("Confusion Matrix")
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")

ax.set_xticks(np.arange(len(class_names)))
ax.set_yticks(np.arange(len(class_names)))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

thresh = cm.max() / 2 if cm.size > 0 else 0

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(
            j, i, format(cm[i, j], "d"),
            ha="center", va="center",
            color="white" if cm[i, j] > thresh else "black"
        )

plt.tight_layout()

save_path = "/content/drive/MyDrive/PlantDiseaseProject/confusion_matrix_best.png"
plt.savefig(save_path, dpi=300, bbox_inches="tight")
plt.show()

print("Saved confusion matrix to:", save_path)
# Out:
# Saved confusion matrix to: /content/drive/MyDrive/PlantDiseaseProject/confusion_matrix_best.png

# %% [markdown]
# Save final metrics to a text file

# %%
result_path = "/content/drive/MyDrive/PlantDiseaseProject/final_metrics.txt"

with open(result_path, "w") as f:
    f.write(f"Best checkpoint epoch: {checkpoint['epoch']}\n")
    f.write(f"Accuracy: {acc*100:.2f}%\n")
    f.write(f"Macro F1: {macro_f1:.4f}\n")

print("Saved metrics to:", result_path)
# Out:
# Saved metrics to: /content/drive/MyDrive/PlantDiseaseProject/final_metrics.txt

# %% [markdown]
# Compare all epochs

# %%
epoch_results = []

for ep in range(1, 21):
    ckpt_path = f"/content/drive/MyDrive/PlantDiseaseProject/student2_dann_fixmatch_epoch_{ep}.pth"
    checkpoint = torch.load(ckpt_path, map_location=device)
    model.load_state_dict(checkpoint["model_state"])

    acc, macro_f1, _, _ = evaluate_model(model, tgt_test_loader, device, source_idx_map)
    epoch_results.append((ep, acc, macro_f1))

print("\nEpoch-wise Results:")
for ep, acc, macro_f1 in epoch_results:
    print(f"Epoch {ep}: Accuracy={acc*100:.2f}% | Macro F1={macro_f1:.4f}")
# Out:
# Accuracy: 29.07%
# Macro F1: 0.1814
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.43      0.33      0.38         9
#                Pepper__bell___healthy       0.57      0.50      0.53         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.56      0.50      0.53        10
#                      Tomato_Leaf_Mold       0.25      0.17      0.20         6
#             Tomato_Septoria_leaf_spot       0.35      0.82      0.49        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.11      0.17      0.13         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.33      0.25      0.29         8
#
#                             micro avg       0.35      0.29      0.32        86
#                             macro avg       0.26      0.27      0.25        86
#                          weighted avg       0.26      0.29      0.26        86
#
# Accuracy: 31.40%
# Macro F1: 0.2086
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.40      0.44      0.42         9
#                Pepper__bell___healthy       1.00      0.50      0.67         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.40      0.60      0.48        10
#                      Tomato_Leaf_Mold       0.33      0.17      0.22         6
#             Tomato_Septoria_leaf_spot       0.26      0.82      0.39        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.29      0.33      0.31         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       1.00      0.12      0.22         8
#
#                             micro avg       0.33      0.31      0.32        86
#                             macro avg       0.37      0.30      0.27        86
#                          weighted avg       0.35      0.31      0.27        86
#
# Accuracy: 32.56%
# Macro F1: 0.2103
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       0.67      0.25      0.36         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.22      0.22      0.22         9
#                    Tomato_Late_blight       0.40      0.60      0.48        10
#                      Tomato_Leaf_Mold       0.22      0.33      0.27         6
#             Tomato_Septoria_leaf_spot       0.47      0.82      0.60        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.29      0.67      0.40         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.22      0.25      0.24         8
#
#                             micro avg       0.35      0.33      0.34        86
#                             macro avg       0.28      0.33      0.27        86
#                          weighted avg       0.28      0.33      0.28        86
#
# Accuracy: 30.23%
# Macro F1: 0.1952
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       0.67      0.50      0.57         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.29      0.22      0.25         9
#                    Tomato_Late_blight       0.30      0.70      0.42        10
#                      Tomato_Leaf_Mold       0.33      0.17      0.22         6
#             Tomato_Septoria_leaf_spot       0.58      0.64      0.61        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.09      0.17      0.12         6
#           Tomato__Tomato_mosaic_virus       1.00      0.10      0.18        10
#                        Tomato_healthy       0.15      0.25      0.19         8
#
#                             micro avg       0.33      0.30      0.32        86
#                             macro avg       0.38      0.29      0.27        86
#                          weighted avg       0.40      0.30      0.29        86
#
# Accuracy: 29.07%
# Macro F1: 0.2066
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.43      0.33      0.38         9
#                Pepper__bell___healthy       0.75      0.38      0.50         8
#                 Tomato_Bacterial_spot       0.33      0.11      0.17         9
#                   Tomato_Early_blight       0.25      0.11      0.15         9
#                    Tomato_Late_blight       0.45      0.50      0.48        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.28      0.82      0.42        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.50      0.10      0.17        10
#                        Tomato_healthy       0.17      0.12      0.14         8
#
#                             micro avg       0.34      0.29      0.31        86
#                             macro avg       0.42      0.26      0.27        86
#                          weighted avg       0.41      0.29      0.28        86
#
# Accuracy: 25.58%
# Macro F1: 0.1621
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       1.00      0.11      0.20         9
#                Pepper__bell___healthy       1.00      0.12      0.22         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.50      0.22      0.31         9
#                    Tomato_Late_blight       0.44      0.70      0.54        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.30      0.64      0.41        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.25      0.10      0.14        10
#                        Tomato_healthy       0.12      0.25      0.16         8
#
#                             micro avg       0.30      0.26      0.28        86
#                             macro avg       0.46      0.23      0.23        86
#                          weighted avg       0.45      0.26      0.24        86
#
# Accuracy: 38.37%
# Macro F1: 0.2680
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.25      0.11      0.15         9
#                Pepper__bell___healthy       0.75      0.75      0.75         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.50      0.11      0.18         9
#                    Tomato_Late_blight       0.45      1.00      0.62        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.50      0.91      0.65        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.29      0.33      0.31         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.29      0.25      0.27         8
#
#                             micro avg       0.46      0.38      0.42        86
#                             macro avg       0.40      0.36      0.32        86
#                          weighted avg       0.38      0.38      0.33        86
#
# Accuracy: 31.40%
# Macro F1: 0.2192
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.67      0.22      0.33         9
#                Pepper__bell___healthy       0.80      0.50      0.62         8
#                 Tomato_Bacterial_spot       0.33      0.11      0.17         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.42      0.80      0.55        10
#                      Tomato_Leaf_Mold       0.50      0.17      0.25         6
#             Tomato_Septoria_leaf_spot       0.36      0.91      0.51        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.50      0.12      0.20         8
#
#                             micro avg       0.39      0.31      0.35        86
#                             macro avg       0.36      0.28      0.26        86
#                          weighted avg       0.36      0.31      0.28        86
#
# Accuracy: 34.88%
# Macro F1: 0.2328
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.50      0.22      0.31         9
#                Pepper__bell___healthy       0.71      0.62      0.67         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.50      0.11      0.18         9
#                    Tomato_Late_blight       0.47      0.90      0.62        10
#                      Tomato_Leaf_Mold       0.50      0.17      0.25         6
#             Tomato_Septoria_leaf_spot       0.34      0.91      0.50        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.29      0.25      0.27         8
#
#                             micro avg       0.40      0.35      0.37        86
#                             macro avg       0.33      0.32      0.28        86
#                          weighted avg       0.33      0.35      0.29        86
#
# Accuracy: 33.72%
# Macro F1: 0.2355
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.50      0.22      0.31         9
#                Pepper__bell___healthy       1.00      0.50      0.67         8
#                 Tomato_Bacterial_spot       1.00      0.11      0.20         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.38      0.90      0.53        10
#                      Tomato_Leaf_Mold       0.50      0.33      0.40         6
#             Tomato_Septoria_leaf_spot       0.35      0.82      0.49        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.22      0.25      0.24         8
#
#                             micro avg       0.39      0.34      0.36        86
#                             macro avg       0.39      0.31      0.28        86
#                          weighted avg       0.39      0.34      0.29        86
#
# Accuracy: 27.91%
# Macro F1: 0.1929
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       0.27      0.50      0.35         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.40      0.22      0.29         9
#                    Tomato_Late_blight       0.33      0.50      0.40        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.37      0.64      0.47        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       1.00      0.20      0.33        10
#                        Tomato_healthy       0.20      0.25      0.22         8
#
#                             micro avg       0.33      0.28      0.30        86
#                             macro avg       0.39      0.26      0.25        86
#                          weighted avg       0.39      0.28      0.27        86
#
# Accuracy: 27.91%
# Macro F1: 0.1701
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.00      0.00      0.00         9
#                Pepper__bell___healthy       0.50      0.38      0.43         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       1.00      0.11      0.20         9
#                    Tomato_Late_blight       0.26      1.00      0.42        10
#                      Tomato_Leaf_Mold       0.50      0.33      0.40         6
#             Tomato_Septoria_leaf_spot       0.43      0.55      0.48        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.33      0.25      0.29         8
#
#                             micro avg       0.31      0.28      0.29        86
#                             macro avg       0.30      0.26      0.22        86
#                          weighted avg       0.30      0.28      0.23        86
#
# Accuracy: 37.21%
# Macro F1: 0.2593
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.00      0.00      0.00         9
#                Pepper__bell___healthy       0.78      0.88      0.82         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.40      0.22      0.29         9
#                    Tomato_Late_blight       0.37      1.00      0.54        10
#                      Tomato_Leaf_Mold       0.67      0.33      0.44         6
#             Tomato_Septoria_leaf_spot       0.40      0.55      0.46        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.25      0.33      0.29         6
#           Tomato__Tomato_mosaic_virus       0.67      0.20      0.31        10
#                        Tomato_healthy       1.00      0.12      0.22         8
#
#                             micro avg       0.43      0.37      0.40        86
#                             macro avg       0.45      0.36      0.34        86
#                          weighted avg       0.44      0.37      0.34        86
#
# Accuracy: 33.72%
# Macro F1: 0.2354
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.00      0.00      0.00         9
#                Pepper__bell___healthy       0.71      0.62      0.67         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       1.00      0.11      0.20         9
#                    Tomato_Late_blight       0.32      1.00      0.49        10
#                      Tomato_Leaf_Mold       0.50      0.17      0.25         6
#             Tomato_Septoria_leaf_spot       0.54      0.64      0.58        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.57      0.40      0.47        10
#                        Tomato_healthy       0.25      0.12      0.17         8
#
#                             micro avg       0.43      0.34      0.38        86
#                             macro avg       0.39      0.31      0.28        86
#                          weighted avg       0.40      0.34      0.30        86
#
# Accuracy: 25.58%
# Macro F1: 0.1729
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       0.50      0.50      0.50         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.33      0.70      0.45        10
#                      Tomato_Leaf_Mold       0.33      0.17      0.22         6
#             Tomato_Septoria_leaf_spot       0.50      0.64      0.56        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        10
#                        Tomato_healthy       0.13      0.25      0.17         8
#
#                             micro avg       0.31      0.26      0.28        86
#                             macro avg       0.21      0.24      0.21        86
#                          weighted avg       0.22      0.26      0.22        86
#
# Accuracy: 29.07%
# Macro F1: 0.1834
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       1.00      0.11      0.20         9
#                Pepper__bell___healthy       0.57      0.50      0.53         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.27      0.60      0.38        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.48      0.91      0.62        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.25      0.10      0.14        10
#                        Tomato_healthy       0.20      0.25      0.22         8
#
#                             micro avg       0.34      0.29      0.31        86
#                             macro avg       0.38      0.26      0.24        86
#                          weighted avg       0.37      0.29      0.25        86
#
# Accuracy: 34.88%
# Macro F1: 0.2630
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.40      0.22      0.29         9
#                Pepper__bell___healthy       0.45      0.62      0.53         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.50      0.33      0.40         9
#                    Tomato_Late_blight       0.54      0.70      0.61        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.60      0.82      0.69        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.50      0.10      0.17        10
#                        Tomato_healthy       0.15      0.25      0.19         8
#
#                             micro avg       0.41      0.35      0.38        86
#                             macro avg       0.41      0.32      0.32        86
#                          weighted avg       0.42      0.35      0.34        86
#
# Accuracy: 30.23%
# Macro F1: 0.2157
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.00      0.00      0.00         9
#                Pepper__bell___healthy       0.57      0.50      0.53         8
#                 Tomato_Bacterial_spot       0.14      0.11      0.12         9
#                   Tomato_Early_blight       0.19      0.33      0.24         9
#                    Tomato_Late_blight       0.35      0.60      0.44        10
#                      Tomato_Leaf_Mold       0.50      0.17      0.25         6
#             Tomato_Septoria_leaf_spot       0.54      0.64      0.58        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.14      0.17      0.15         6
#           Tomato__Tomato_mosaic_virus       0.67      0.20      0.31        10
#                        Tomato_healthy       0.25      0.12      0.17         8
#
#                             micro avg       0.34      0.30      0.32        86
#                             macro avg       0.34      0.28      0.28        86
#                          weighted avg       0.34      0.30      0.29        86
#
# Accuracy: 33.72%
# Macro F1: 0.2432
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       0.43      0.38      0.40         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.67      0.22      0.33         9
#                    Tomato_Late_blight       0.48      1.00      0.65        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.40      0.73      0.52        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       0.50      0.20      0.29        10
#                        Tomato_healthy       0.33      0.25      0.29         8
#
#                             micro avg       0.38      0.34      0.36        86
#                             macro avg       0.41      0.31      0.29        86
#                          weighted avg       0.41      0.34      0.31        86
#
# Accuracy: 26.74%
# Macro F1: 0.1767
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#         Pepper__bell___Bacterial_spot       0.33      0.11      0.17         9
#                Pepper__bell___healthy       1.00      0.12      0.22         8
#                 Tomato_Bacterial_spot       0.00      0.00      0.00         9
#                   Tomato_Early_blight       0.00      0.00      0.00         9
#                    Tomato_Late_blight       0.29      0.70      0.41        10
#                      Tomato_Leaf_Mold       1.00      0.17      0.29         6
#             Tomato_Septoria_leaf_spot       0.38      0.82      0.51        11
# Tomato__Tomato_YellowLeaf__Curl_Virus       0.00      0.00      0.00         6
#           Tomato__Tomato_mosaic_virus       1.00      0.20      0.33        10
#                        Tomato_healthy       0.67      0.25      0.36         8
#
#                             micro avg       0.37      0.27      0.31        86
#                             macro avg       0.47      0.24      0.23        86
#                          weighted avg       0.46      0.27      0.24        86
#
#
# Epoch-wise Results:
# Epoch 1: Accuracy=29.07% | Macro F1=0.1814
# Epoch 2: Accuracy=31.40% | Macro F1=0.2086
# Epoch 3: Accuracy=32.56% | Macro F1=0.2103
# Epoch 4: Accuracy=30.23% | Macro F1=0.1952
# Epoch 5: Accuracy=29.07% | Macro F1=0.2066
# Epoch 6: Accuracy=25.58% | Macro F1=0.1621
# Epoch 7: Accuracy=38.37% | Macro F1=0.2680
# Epoch 8: Accuracy=31.40% | Macro F1=0.2192
# Epoch 9: Accuracy=34.88% | Macro F1=0.2328
# Epoch 10: Accuracy=33.72% | Macro F1=0.2355
# Epoch 11: Accuracy=27.91% | Macro F1=0.1929
# Epoch 12: Accuracy=27.91% | Macro F1=0.1701
# Epoch 13: Accuracy=37.21% | Macro F1=0.2593
# Epoch 14: Accuracy=33.72% | Macro F1=0.2354
# Epoch 15: Accuracy=25.58% | Macro F1=0.1729
# Epoch 16: Accuracy=29.07% | Macro F1=0.1834
# Epoch 17: Accuracy=34.88% | Macro F1=0.2630
# Epoch 18: Accuracy=30.23% | Macro F1=0.2157
# Epoch 19: Accuracy=33.72% | Macro F1=0.2432
# Epoch 20: Accuracy=26.74% | Macro F1=0.1767
